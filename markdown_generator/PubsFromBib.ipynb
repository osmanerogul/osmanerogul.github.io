# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "article": {
        "file" : "oepapers.bib",
        "venuekey": "title",
        "venue-pretext": "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "inproceedings":{
        "file": "oepapers.bib",
        "venuekey" : "title",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED Kuru2021: " Autonomous Low Power Monitoring Sensors  "
# SUCESSFULLY PARSED Karagoz1999: " Ileri Teknoloji urunu Tbbi Cihazlarin Bakim Onarimlarinin Ha ... "
# SUCESSFULLY PARSED Dogan2011: " Uyku apne sendromunun ust havayolu scaklk degisimi ve oksije ... "
# SUCESSFULLY PARSED erogul2000: " Obtaining gracefully degraded federal standard melp quality  ... "
# SUCESSFULLY PARSED Saraydemir2015: " Effects of Training Set Dimension on Recognition of Dysmorph ... "
# SUCESSFULLY PARSED Ozdemir2022: " Development of Radiant Warmer Thermal Monitoring System to I ... "
# SUCESSFULLY PARSED Galip2018: " Emerging Approaches in Analysis and Evaluation in Sports Sci ... "
# SUCESSFULLY PARSED Savaser2017: " Patient specific implant design and production for closure o ... "
# SUCESSFULLY PARSED Budak2019: " Smart tourniquet system for military use  "
# SUCESSFULLY PARSED Ozdemir2019: " Performance comparison of segmentation algorithms for image  ... "
# SUCESSFULLY PARSED Erkinay2012: " Dysmorphic Syndromes Classification and Recognition with Com ... "
# SUCESSFULLY PARSED Sahin2017: " Computer-assisted diagnosis of osteoartrithis on hip radiogr ... "
# SUCESSFULLY PARSED Bayrak2012: " Uyku Apnesi Parametrelerinin Cerrahi Tedavi Oncesi ve Sonras ... "
# SUCESSFULLY PARSED erogull2000: " Time-scale modification of speech signals based on wavelet t ... "
# SUCESSFULLY PARSED karagozz1999: " A new 3-D double window adaptive hybrid smoothing algorithm  ... "
# SUCESSFULLY PARSED Erogul1999: " Multiresolutional modification of speech signals for listene ... "
# SUCESSFULLY PARSED Kocak2023: " Defining, Detecting and Assessment of Microstructures in Dif ... "
# SUCESSFULLY PARSED Yesildaglar2003: " Reduction of CO2 pneumoperitoneum induced metabolic hypoxaem ... "
# SUCESSFULLY PARSED UYAR2023: " Automated Cell Viability Analysis in Tissue Scaffolds  "
# SUCESSFULLY PARSED Fen2018: " Anahtarlamali Reluktans Motor Tabanli Medikal Santrifuj Sist ... "
# SUCESSFULLY PARSED gOzdemirr2016: " An early warning algorithm to predict obstructive sleep apne ... "
# SUCESSFULLY PARSED Nasifoglu2017: " Multi-regional adaptive image compression (AIC) for hip frac ... "
# SUCESSFULLY PARSED Cavusoglu2007: " SASA: a software system for sleep and snoring analysis  "
# SUCESSFULLY PARSED Ozdemirr2019: " Investigating ballistic gelatin based phantom properties for ... "
# SUCESSFULLY PARSED Demirbag2005: " The addition of O2 to the CO2 does not prevent the systemic  ... "
# SUCESSFULLY PARSED karagoz1998: " A new dynamic renal phantom and its application to scintigra ... "
# SUCESSFULLY PARSED Budak2017: " Lower limb phantom design and production for blood flow and  ... "
# SUCESSFULLY PARSED Ficicii2023: " Localization of epileptic focus by gray matter reduction ana ... "
# SUCESSFULLY PARSED Ficici2023: " Identification of TLE Focus from EEG Signals by Using Deep L ... "
# SUCESSFULLY PARSED Kocak2009: " Turkiyede Biyomedikal Muhendisligi Egitimi, Uygulamalar ve I ... "
# SUCESSFULLY PARSED Ficici2017: " Fully automated brain tumor segmentation and volume estimati ... "
# SUCESSFULLY PARSED Cavusoglu2008: " Spectral envelope analysis of snoring signals  "
# SUCESSFULLY PARSED Nasifoglu2021: " Obstructive sleep apnea prediction from electrocardiogram sc ... "
# SUCESSFULLY PARSED Yasar2020: " Capacitive micromachined ultrasonic transducer: transmission ... "
# SUCESSFULLY PARSED Aksahin2015: " Obstructive sleep apnea classification with artificial neura ... "
# SUCESSFULLY PARSED Eken2023: " Diagnostic Machine Learning Applications on Clinical Populat ... "
# SUCESSFULLY PARSED Erkinay2018: " Classifying dysmorphic syndromes by using artificial neural  ... "
# SUCESSFULLY PARSED Duman2005: " Automatic sleep spindle detection and localization algorithm  "
# SUCESSFULLY PARSED Cavusoglu2005: " Design and implemantation of a programmable apnea monitoring ... "
# SUCESSFULLY PARSED Yildiz2010: " Measurement system of thermal pain threshold and response ti ... "
# SUCESSFULLY PARSED Demirgunes2011: " Segmentation of breast region from MR images using multi-sta ... "
# SUCESSFULLY PARSED Erogul1998: " Time-scale modification of speech signals for language-learn ... "
# SUCESSFULLY PARSED Dumann2005: " A hybrid short and long term analysis of sleep spindles  "
# SUCESSFULLY PARSED Cavusogluu2005: " Design and implemantation of a programmable apnea monitoring ... "
# SUCESSFULLY PARSED Cavusogluu2007: " Spectral Envelope Analysis for Simple Snorers and Obstructiv ... "
# SUCESSFULLY PARSED Demirgunes2009: " Analysis of respiration, oxygen saturation and acoustic sign ... "
# SUCESSFULLY PARSED Yildizz2010: " Measurement system of thermal pain threshold and response ti ... "
# SUCESSFULLY PARSED Aksahin2010: " Classification of sleep apnea types using EEG synchronizatio ... "
# SUCESSFULLY PARSED Ertas2012: " Conventional and multi-state cellular neural networks in seg ... "
# SUCESSFULLY PARSED Saraydemir2014: " A medical decision support system based on Gabor fisher clas ... "
# SUCESSFULLY PARSED Cavusoglu2014: " Automatic detection of snore episodes in paediatric populati ... "
# SUCESSFULLY PARSED Ficici2019: " Epileptic Activity Detection in EEG Signals using Linear and ... "
# SUCESSFULLY PARSED Yasar2019: " Evaluation of CMUT Performance Under Different Excitation Si ... "
# SUCESSFULLY PARSED Nassehi2020: " A Study On Finding The Optimal Time For Automatic Transition ... "
# SUCESSFULLY PARSED Sahin2020: " Design of a Wireless Polysomnography System  "
# SUCESSFULLY PARSED Ozdemir2020: " Development of Invasive Blood Pressure Simulator Design for  ... "
# SUCESSFULLY PARSED Dagli2020: " Classification of Brain Tumors via Deep Learning Models  "
# SUCESSFULLY PARSED Nassehii2020: " Investigating EEG Based Marker for Diagnosis of Mathematical ... "
# SUCESSFULLY PARSED Nassehi2022: " Detection of Attention Deficit and Hyperactivity Disorder by ... "
# SUCESSFULLY PARSED Gokcinar2022: " A Mathematical Model of Infant Thermoregulation System for I ... "
# SUCESSFULLY PARSED Altunay2006: " Interpretation of Uroflow Graphs with Artificial Neural Netw ... "
# SUCESSFULLY PARSED Cavusoglu2006: " Analysing Snoring Sounds For Obstructive Sleep Apnea (OSA) P ... "
# SUCESSFULLY PARSED Erdamar2006: " Determination of Obstructive Sleep Apnea from Polisomnograph ... "
# SUCESSFULLY PARSED Erogul2009: " Recognition of Down syndromes using image analysis  "
# SUCESSFULLY PARSED gOzdemir2016: " A time-series approach to predict obstructive sleep apnea (O ... "
# SUCESSFULLY PARSED Tugrull2019: " Analysis of water-equivalent materials used during irradiati ... "
# SUCESSFULLY PARSED Ozturk2023: " Differentiation of Benign and Malignant Thyroid Nodules with ... "
# SUCESSFULLY PARSED Kocak2017: " Kamu Ozel ortakligi hastaneleri icin tibbi atik yOnetim mode ... "
# SUCESSFULLY PARSED Akkur2022: " Breast Cancer Diagnosis Using Feature Selection Approaches a ... "
# SUCESSFULLY PARSED Ficiciii2023: " Automatic Brain Tumor Detection and Volume Estimation in Mul ... "
# SUCESSFULLY PARSED Kocak2012: " Automated detection and classification of sleep apnea types  ... "
# SUCESSFULLY PARSED Ficici2022: " Automated temporal lobe epilepsy and psychogenic nonepilepti ... "
# SUCESSFULLY PARSED Altunay2009: " A new approach to urinary system dynamics problems: Evaluati ... "
# SUCESSFULLY PARSED Nasifoglu2019: " Medical Image Compression for Telemedicine Applications  "
# SUCESSFULLY PARSED Ozguzar2023: " Plasma-Assisted Surface Modification and Heparin Immobilizat ... "
# SUCESSFULLY PARSED Tugrul2019: " Determination of initial electron parameters by means of Mon ... "
# SUCESSFULLY PARSED Subasi2005: " Automatic recognition of vigilance state by using a wavelet- ... "
# SUCESSFULLY PARSED Ilk2002: " Effects of Tonsillectomy on Speech Spectrum  "
# SUCESSFULLY PARSED Duman2009: " Efficient sleep spindle detection algorithm with decision tr ... "
# SUCESSFULLY PARSED Saraydemir2012: " Down syndrome diagnosis based on gabor wavelet transform  "
# SUCESSFULLY PARSED Altunay2010: " Epileptic EEG detection using the linear prediction error en ... "
# SUCESSFULLY PARSED Kuru2021: " Autonomous Low Power Monitoring Sensors  "
# SUCESSFULLY PARSED Karagoz1999: " Ileri Teknoloji urunu Tbbi Cihazlarin Bakim Onarimlarinin Ha ... "
# SUCESSFULLY PARSED Dogan2011: " Uyku apne sendromunun ust havayolu scaklk degisimi ve oksije ... "
# SUCESSFULLY PARSED erogul2000: " Obtaining gracefully degraded federal standard melp quality  ... "
# SUCESSFULLY PARSED Saraydemir2015: " Effects of Training Set Dimension on Recognition of Dysmorph ... "
# SUCESSFULLY PARSED Ozdemir2022: " Development of Radiant Warmer Thermal Monitoring System to I ... "
# SUCESSFULLY PARSED Galip2018: " Emerging Approaches in Analysis and Evaluation in Sports Sci ... "
# SUCESSFULLY PARSED Savaser2017: " Patient specific implant design and production for closure o ... "
# SUCESSFULLY PARSED Budak2019: " Smart tourniquet system for military use  "
# SUCESSFULLY PARSED Ozdemir2019: " Performance comparison of segmentation algorithms for image  ... "
# SUCESSFULLY PARSED Erkinay2012: " Dysmorphic Syndromes Classification and Recognition with Com ... "
# SUCESSFULLY PARSED Sahin2017: " Computer-assisted diagnosis of osteoartrithis on hip radiogr ... "
# SUCESSFULLY PARSED Bayrak2012: " Uyku Apnesi Parametrelerinin Cerrahi Tedavi Oncesi ve Sonras ... "
# SUCESSFULLY PARSED erogull2000: " Time-scale modification of speech signals based on wavelet t ... "
# SUCESSFULLY PARSED karagozz1999: " A new 3-D double window adaptive hybrid smoothing algorithm  ... "
# SUCESSFULLY PARSED Erogul1999: " Multiresolutional modification of speech signals for listene ... "
# SUCESSFULLY PARSED Kocak2023: " Defining, Detecting and Assessment of Microstructures in Dif ... "
# SUCESSFULLY PARSED Yesildaglar2003: " Reduction of CO2 pneumoperitoneum induced metabolic hypoxaem ... "
# SUCESSFULLY PARSED UYAR2023: " Automated Cell Viability Analysis in Tissue Scaffolds  "
# SUCESSFULLY PARSED Fen2018: " Anahtarlamali Reluktans Motor Tabanli Medikal Santrifuj Sist ... "
# SUCESSFULLY PARSED gOzdemirr2016: " An early warning algorithm to predict obstructive sleep apne ... "
# SUCESSFULLY PARSED Nasifoglu2017: " Multi-regional adaptive image compression (AIC) for hip frac ... "
# SUCESSFULLY PARSED Cavusoglu2007: " SASA: a software system for sleep and snoring analysis  "
# SUCESSFULLY PARSED Ozdemirr2019: " Investigating ballistic gelatin based phantom properties for ... "
# SUCESSFULLY PARSED Demirbag2005: " The addition of O2 to the CO2 does not prevent the systemic  ... "
# SUCESSFULLY PARSED karagoz1998: " A new dynamic renal phantom and its application to scintigra ... "
# SUCESSFULLY PARSED Budak2017: " Lower limb phantom design and production for blood flow and  ... "
# SUCESSFULLY PARSED Ficicii2023: " Localization of epileptic focus by gray matter reduction ana ... "
# SUCESSFULLY PARSED Ficici2023: " Identification of TLE Focus from EEG Signals by Using Deep L ... "
# SUCESSFULLY PARSED Kocak2009: " Turkiyede Biyomedikal Muhendisligi Egitimi, Uygulamalar ve I ... "
# SUCESSFULLY PARSED Ficici2017: " Fully automated brain tumor segmentation and volume estimati ... "
# SUCESSFULLY PARSED Cavusoglu2008: " Spectral envelope analysis of snoring signals  "
# SUCESSFULLY PARSED Nasifoglu2021: " Obstructive sleep apnea prediction from electrocardiogram sc ... "
# SUCESSFULLY PARSED Yasar2020: " Capacitive micromachined ultrasonic transducer: transmission ... "
# SUCESSFULLY PARSED Aksahin2015: " Obstructive sleep apnea classification with artificial neura ... "
# SUCESSFULLY PARSED Eken2023: " Diagnostic Machine Learning Applications on Clinical Populat ... "
# SUCESSFULLY PARSED Erkinay2018: " Classifying dysmorphic syndromes by using artificial neural  ... "
# SUCESSFULLY PARSED Duman2005: " Automatic sleep spindle detection and localization algorithm  "
# SUCESSFULLY PARSED Cavusoglu2005: " Design and implemantation of a programmable apnea monitoring ... "
# SUCESSFULLY PARSED Yildiz2010: " Measurement system of thermal pain threshold and response ti ... "
# SUCESSFULLY PARSED Demirgunes2011: " Segmentation of breast region from MR images using multi-sta ... "
# SUCESSFULLY PARSED Erogul1998: " Time-scale modification of speech signals for language-learn ... "
# SUCESSFULLY PARSED Dumann2005: " A hybrid short and long term analysis of sleep spindles  "
# SUCESSFULLY PARSED Cavusogluu2005: " Design and implemantation of a programmable apnea monitoring ... "
# SUCESSFULLY PARSED Cavusogluu2007: " Spectral Envelope Analysis for Simple Snorers and Obstructiv ... "
# SUCESSFULLY PARSED Demirgunes2009: " Analysis of respiration, oxygen saturation and acoustic sign ... "
# SUCESSFULLY PARSED Yildizz2010: " Measurement system of thermal pain threshold and response ti ... "
# SUCESSFULLY PARSED Aksahin2010: " Classification of sleep apnea types using EEG synchronizatio ... "
# SUCESSFULLY PARSED Ertas2012: " Conventional and multi-state cellular neural networks in seg ... "
# SUCESSFULLY PARSED Saraydemir2014: " A medical decision support system based on Gabor fisher clas ... "
# SUCESSFULLY PARSED Cavusoglu2014: " Automatic detection of snore episodes in paediatric populati ... "
# SUCESSFULLY PARSED Ficici2019: " Epileptic Activity Detection in EEG Signals using Linear and ... "
# SUCESSFULLY PARSED Yasar2019: " Evaluation of CMUT Performance Under Different Excitation Si ... "
# SUCESSFULLY PARSED Nassehi2020: " A Study On Finding The Optimal Time For Automatic Transition ... "
# SUCESSFULLY PARSED Sahin2020: " Design of a Wireless Polysomnography System  "
# SUCESSFULLY PARSED Ozdemir2020: " Development of Invasive Blood Pressure Simulator Design for  ... "
# SUCESSFULLY PARSED Dagli2020: " Classification of Brain Tumors via Deep Learning Models  "
# SUCESSFULLY PARSED Nassehii2020: " Investigating EEG Based Marker for Diagnosis of Mathematical ... "
# SUCESSFULLY PARSED Nassehi2022: " Detection of Attention Deficit and Hyperactivity Disorder by ... "
# SUCESSFULLY PARSED Gokcinar2022: " A Mathematical Model of Infant Thermoregulation System for I ... "
# SUCESSFULLY PARSED Altunay2006: " Interpretation of Uroflow Graphs with Artificial Neural Netw ... "
# SUCESSFULLY PARSED Cavusoglu2006: " Analysing Snoring Sounds For Obstructive Sleep Apnea (OSA) P ... "
# SUCESSFULLY PARSED Erdamar2006: " Determination of Obstructive Sleep Apnea from Polisomnograph ... "
# SUCESSFULLY PARSED Erogul2009: " Recognition of Down syndromes using image analysis  "
# SUCESSFULLY PARSED gOzdemir2016: " A time-series approach to predict obstructive sleep apnea (O ... "
# SUCESSFULLY PARSED Tugrull2019: " Analysis of water-equivalent materials used during irradiati ... "
# SUCESSFULLY PARSED Ozturk2023: " Differentiation of Benign and Malignant Thyroid Nodules with ... "
# SUCESSFULLY PARSED Kocak2017: " Kamu Ozel ortakligi hastaneleri icin tibbi atik yOnetim mode ... "
# SUCESSFULLY PARSED Akkur2022: " Breast Cancer Diagnosis Using Feature Selection Approaches a ... "
# SUCESSFULLY PARSED Ficiciii2023: " Automatic Brain Tumor Detection and Volume Estimation in Mul ... "
# SUCESSFULLY PARSED Kocak2012: " Automated detection and classification of sleep apnea types  ... "
# SUCESSFULLY PARSED Ficici2022: " Automated temporal lobe epilepsy and psychogenic nonepilepti ... "
# SUCESSFULLY PARSED Altunay2009: " A new approach to urinary system dynamics problems: Evaluati ... "
# SUCESSFULLY PARSED Nasifoglu2019: " Medical Image Compression for Telemedicine Applications  "
# SUCESSFULLY PARSED Ozguzar2023: " Plasma-Assisted Surface Modification and Heparin Immobilizat ... "
# SUCESSFULLY PARSED Tugrul2019: " Determination of initial electron parameters by means of Mon ... "
# SUCESSFULLY PARSED Subasi2005: " Automatic recognition of vigilance state by using a wavelet- ... "
# SUCESSFULLY PARSED Ilk2002: " Effects of Tonsillectomy on Speech Spectrum  "
# SUCESSFULLY PARSED Duman2009: " Efficient sleep spindle detection algorithm with decision tr ... "
# SUCESSFULLY PARSED Saraydemir2012: " Down syndrome diagnosis based on gabor wavelet transform  "
# SUCESSFULLY PARSED Altunay2010: " Epileptic EEG detection using the linear prediction error en ... "
